# %% [markdown]
#  # **Python Reinforcement Project**

# %% [markdown]
# # **Laptop Dataset Analysis**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
import datetime as dt
import warnings
warnings.filterwarnings('ignore')

# %%
laptopdata=pd.read_csv(r"D:\Python_Project\laptopData.csv")
laptopdata
# Out:
#       Unnamed: 0 Company            TypeName Inches  \
# 0            0.0   Apple           Ultrabook   13.3
# 1            1.0   Apple           Ultrabook   13.3
# 2            2.0      HP            Notebook   15.6
# 3            3.0   Apple           Ultrabook   15.4
# 4            4.0   Apple           Ultrabook   13.3
# ...          ...     ...                 ...    ...
# 1298      1298.0  Lenovo  2 in 1 Convertible     14
# 1299      1299.0  Lenovo  2 in 1 Convertible   13.3
# 1300      1300.0  Lenovo            Notebook   65.4
# 1301      1301.0      HP            Notebook   15.6
# 1302      1302.0    Asus            Notebook   15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
laptop_df=laptopdata.copy()

# %%
laptop_df
# Out:
#       Unnamed: 0 Company            TypeName Inches  \
# 0            0.0   Apple           Ultrabook   13.3
# 1            1.0   Apple           Ultrabook   13.3
# 2            2.0      HP            Notebook   15.6
# 3            3.0   Apple           Ultrabook   15.4
# 4            4.0   Apple           Ultrabook   13.3
# ...          ...     ...                 ...    ...
# 1298      1298.0  Lenovo  2 in 1 Convertible     14
# 1299      1299.0  Lenovo  2 in 1 Convertible   13.3
# 1300      1300.0  Lenovo            Notebook   65.4
# 1301      1301.0      HP            Notebook   15.6
# 1302      1302.0    Asus            Notebook   15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %% [markdown]
# # Shape of the Dataset

# %%
laptop_df.shape
# Out:
# (1303, 12)

# %%
laptop_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1273 non-null   float64
#  1   Company           1273 non-null   object
#  2   TypeName          1253 non-null   object
#  3   Inches            1220 non-null   object
#  4   ScreenResolution  1273 non-null   object
#  5   Cpu               1273 non-null   object
#  6   Ram               1259 non-null   object
#  7   Memory            1273 non-null   object
#  8   Gpu               1273 non-null   object
#  9   OpSys             1273 non-null   object
#  10  Weight            1259 non-null   object
#  11  Price             1273 non-null   float64
# dtypes: float64(2), object(10)
# memory usage: 122.3+ KB

# %% [markdown]
# # Description of the Dataset

# %%
laptop_df.describe()
# Out:
#         Unnamed: 0          Price
# count  1273.000000    1273.000000
# mean    652.674784   59955.814073
# std     376.493027   37332.251005
# min       0.000000    9270.720000
# 25%     327.000000   31914.720000
# 50%     652.000000   52161.120000
# 75%     980.000000   79333.387200
# max    1302.000000  324954.720000

# %% [markdown]
# # Variables in the Dataset

# %%
set(laptop_df)
# Out:
# {'Company',
#  'Cpu',
#  'Gpu',
#  'Inches',
#  'Memory',
#  'OpSys',
#  'Price',
#  'Ram',
#  'ScreenResolution',
#  'TypeName',
#  'Unnamed: 0',
#  'Weight'}

# %%
laptop_df.isnull().sum()
# Out:
# Unnamed: 0          30
# Company             30
# TypeName            50
# Inches              83
# ScreenResolution    30
# Cpu                 30
# Ram                 44
# Memory              30
# Gpu                 30
# OpSys               30
# Weight              44
# Price               30
# dtype: int64

# %%
laptop_df.isnull().sum().sum()
# Out:
# 461

# %% [markdown]
# # Null values in percentage

# %%
round((laptop_df.isnull().sum()/len(laptop_df.index))*100,2).sort_values(ascending=False)
# Out:
# Inches              6.37
# TypeName            3.84
# Ram                 3.38
# Weight              3.38
# Unnamed: 0          2.30
# Company             2.30
# ScreenResolution    2.30
# Cpu                 2.30
# Memory              2.30
# Gpu                 2.30
# OpSys               2.30
# Price               2.30
# dtype: float64

# %% [markdown]
# ### Dropping columns if 50% values are missing

# %%
laptop_df = laptop_df.dropna(axis=1,thresh=int(len(laptop_df.index)/2))

# %%
# Percentage of missing values in each column corresponding to total number of records after dropping columns

round(100*(laptop_df.isnull().sum()/len(laptop_df.index)), 2).sort_values(ascending=False).head(15)
# Out:
# Inches              6.37
# TypeName            3.84
# Ram                 3.38
# Weight              3.38
# Unnamed: 0          2.30
# Company             2.30
# ScreenResolution    2.30
# Cpu                 2.30
# Memory              2.30
# Gpu                 2.30
# OpSys               2.30
# Price               2.30
# dtype: float64

# %%
set(laptop_df)
# Out:
# {'Company',
#  'Cpu',
#  'Gpu',
#  'Inches',
#  'Memory',
#  'OpSys',
#  'Price',
#  'Ram',
#  'ScreenResolution',
#  'TypeName',
#  'Unnamed: 0',
#  'Weight'}

# %%
# Maximum number of missing values across the rows of the dataset

laptop_df.isnull().sum(axis=1).max()
# Out:
# 12

# %%
laptop_df.shape
# Out:
# (1303, 12)

# %% [markdown]
# # Data Cleaning

# %%
laptop_df=laptop_df.drop("Unnamed: 0",axis=1)

# %%
laptop_df.drop(columns='Unnamed: 0', inplace=True, errors='ignore')

# %%
set(laptop_df)
# Out:
# {'Company',
#  'Cpu',
#  'Gpu',
#  'Inches',
#  'Memory',
#  'OpSys',
#  'Price',
#  'Ram',
#  'ScreenResolution',
#  'TypeName',
#  'Weight'}

# %%
# Unique values of each columns of the dataframe
laptop_df.apply(lambda x:x .unique())
# Out:
# Company             [Apple, HP, Acer, Asus, Dell, Lenovo, nan, Chu...
# TypeName            [Ultrabook, Notebook, nan, Gaming, 2 in 1 Conv...
# Inches              [13.3, 15.6, 15.4, 14, 12, nan, 17.3, 13.5, 12...
# ScreenResolution    [IPS Panel Retina Display 2560x1600, 1440x900,...
# Cpu                 [Intel Core i5 2.3GHz, Intel Core i5 1.8GHz, I...
# Ram                 [8GB, 16GB, 4GB, nan, 2GB, 12GB, 64GB, 6GB, 32...
# Memory              [128GB SSD, 128GB Flash Storage, 256GB SSD, 51...
# Gpu                 [Intel Iris Plus Graphics 640, Intel HD Graphi...
# OpSys               [macOS, No OS, Windows 10, Mac OS X, nan, Linu...
# Weight              [1.37kg, 1.34kg, 1.86kg, 1.83kg, 2.1kg, 2.04kg...
# Price               [71378.6832, 47895.5232, 30636.0, 135195.336, ...
# dtype: object

# %% [markdown]
# # Fixing Missing Values

# %%
# Deleting Duplicates
laptop_df.dropna(how='all', inplace=True)

# %%
laptop_df.isnull().sum().sum()
# Out:
# 101

# %%
laptop_df.isnull().sum()
# Out:
# Company              0
# TypeName            20
# Inches              53
# ScreenResolution     0
# Cpu                  0
# Ram                 14
# Memory               0
# Gpu                  0
# OpSys                0
# Weight              14
# Price                0
# dtype: int64

# %%
laptop_df["Inches"].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1298    False
# 1299    False
# 1300    False
# 1301    False
# 1302    False
# Name: Inches, Length: 1273, dtype: bool

# %%
# Replace '?' and empty strings with NaN
laptop_df.replace(['?', 'NA', ''], np.nan, inplace=True)

# %%
laptop_df = laptop_df.dropna(how = "all")
laptop_df
# Out:
#      Company            TypeName Inches  \
# 0      Apple           Ultrabook   13.3
# 1      Apple           Ultrabook   13.3
# 2         HP            Notebook   15.6
# 3      Apple           Ultrabook   15.4
# 4      Apple           Ultrabook   13.3
# ...      ...                 ...    ...
# 1298  Lenovo  2 in 1 Convertible     14
# 1299  Lenovo  2 in 1 Convertible   13.3
# 1300  Lenovo            Notebook   65.4
# 1301      HP            Notebook   15.6
# 1302    Asus            Notebook   15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
laptop_df.isnull().sum()
# Out:
# Company              0
# TypeName            20
# Inches              54
# ScreenResolution     0
# Cpu                  0
# Ram                 14
# Memory               1
# Gpu                  0
# OpSys                0
# Weight              15
# Price                0
# dtype: int64

# %%
laptop_df.isnull().sum().sum()
# Out:
# 104

# %%
# Unique values of each columns in the dataframe (to determine the repetitve or same values of columns)

laptop_df.apply(lambda x : x.unique())
# Out:
# Company             [Apple, HP, Acer, Asus, Dell, Lenovo, Chuwi, M...
# TypeName            [Ultrabook, Notebook, Gaming, 2 in 1 Convertib...
# Inches              [13.3, 15.6, 15.4, 14, 12, 17.3, 13.5, 12.5, 1...
# ScreenResolution    [IPS Panel Retina Display 2560x1600, 1440x900,...
# Cpu                 [Intel Core i5 2.3GHz, Intel Core i5 1.8GHz, I...
# Ram                 [8GB, 16GB, 4GB, nan, 2GB, 12GB, 64GB, 6GB, 32...
# Memory              [128GB SSD, 128GB Flash Storage, 256GB SSD, 51...
# Gpu                 [Intel Iris Plus Graphics 640, Intel HD Graphi...
# OpSys               [macOS, No OS, Windows 10, Mac OS X, Linux, Wi...
# Weight              [1.37kg, 1.34kg, 1.86kg, 1.83kg, 2.1kg, 2.04kg...
# Price               [71378.6832, 47895.5232, 30636.0, 135195.336, ...
# dtype: object

# %%
laptop_df.nunique()
# Out:
# Company              19
# TypeName              6
# Inches               32
# ScreenResolution     40
# Cpu                 118
# Ram                  10
# Memory               39
# Gpu                 110
# OpSys                 9
# Weight              195
# Price               777
# dtype: int64

# %%
laptop_df.isnull().sum(axis=0)
# Out:
# Company              0
# TypeName            20
# Inches              54
# ScreenResolution     0
# Cpu                  0
# Ram                 14
# Memory               1
# Gpu                  0
# OpSys                0
# Weight              15
# Price                0
# dtype: int64

# %% [markdown]
# ### Filling Mode value in null values

# %%
# Fill categorical columns with mode
laptop_df['TypeName'].fillna(laptop_df['TypeName'].mode()[0], inplace=True)
laptop_df['Inches'].fillna(laptop_df['Inches'].mode()[0], inplace=True)
laptop_df['Ram'].fillna(laptop_df['Ram'].mode()[0], inplace=True)
laptop_df["Memory"].fillna(laptop_df["Memory"].mode()[0],inplace=True)

# %%
# Remove 'kg' or 'KG' and convert to float
laptop_df['Weight'] = laptop_df['Weight'].astype(str).str.replace(r'[Kk][Gg]', '', regex=True).astype(float)

# Now fill missing values with the median
median_weight = laptop_df['Weight'].median()
laptop_df['Weight'].fillna(median_weight, inplace=True)

# %%
laptop_df.isnull().sum()
# Out:
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %% [markdown]
# # Standardizing Values

# %%
# Information about the dataframe laptop_df

laptop_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1273 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1273 non-null   object
#  1   TypeName          1273 non-null   object
#  2   Inches            1273 non-null   object
#  3   ScreenResolution  1273 non-null   object
#  4   Cpu               1273 non-null   object
#  5   Ram               1273 non-null   object
#  6   Memory            1273 non-null   object
#  7   Gpu               1273 non-null   object
#  8   OpSys             1273 non-null   object
#  9   Weight            1273 non-null   float64
#  10  Price             1273 non-null   float64
# dtypes: float64(2), object(9)
# memory usage: 119.3+ KB

# %%
# Columns that has to be converted to "numeric" (int or float) type

# Convert numeric-looking columns
# Ensure all values are strings first
laptop_df['Ram'] = laptop_df['Ram'].astype(str).str.replace('GB', '').astype(float).astype(int)

laptop_df['Inches'] = laptop_df['Inches'].astype(float)
laptop_df['Weight'] = laptop_df['Weight'].astype(str).str.replace(r'[Kk][Gg]', '', regex=True).astype(float)
laptop_df['Price'] = laptop_df['Price'].astype(float)

# %%
# Renaming Columns
laptop_df=laptop_df.rename(columns={"Ram":"Ram in GB"})

# %%
laptop_df=laptop_df.rename(columns={"Weight":"Weight in kg"})

# %%
laptop_df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    65.4
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
laptop_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1273 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1273 non-null   object
#  1   TypeName          1273 non-null   object
#  2   Inches            1273 non-null   float64
#  3   ScreenResolution  1273 non-null   object
#  4   Cpu               1273 non-null   object
#  5   Ram in GB         1273 non-null   int32
#  6   Memory            1273 non-null   object
#  7   Gpu               1273 non-null   object
#  8   OpSys             1273 non-null   object
#  9   Weight in kg      1273 non-null   float64
#  10  Price             1273 non-null   float64
# dtypes: float64(3), int32(1), object(7)
# memory usage: 114.4+ KB

# %%
# Pick up the columns of 'float' type to round off them to 2 decimal places (standardizing)

roundOff_float_cols = laptop_df.select_dtypes(include=['float'] )
roundOff_float_cols
# Out:
#       Inches  Weight in kg        Price
# 0       13.3          1.37   71378.6832
# 1       13.3          1.34   47895.5232
# 2       15.6          1.86   30636.0000
# 3       15.4          1.83  135195.3360
# 4       13.3          1.37   96095.8080
# ...      ...           ...          ...
# 1298    14.0          1.80   33992.6400
# 1299    13.3          1.30   79866.7200
# 1300    65.4          1.50   12201.1200
# 1301    15.6          2.19   40705.9200
# 1302    15.6          2.20   19660.3200
#
# [1273 rows x 3 columns]

# %%
# Round off float values to 2 decimal places

for column in roundOff_float_cols:
    laptop_df[column] = laptop_df[column].round(2)

# %%
laptop_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1273 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1273 non-null   object
#  1   TypeName          1273 non-null   object
#  2   Inches            1273 non-null   float64
#  3   ScreenResolution  1273 non-null   object
#  4   Cpu               1273 non-null   object
#  5   Ram in GB         1273 non-null   int32
#  6   Memory            1273 non-null   object
#  7   Gpu               1273 non-null   object
#  8   OpSys             1273 non-null   object
#  9   Weight in kg      1273 non-null   float64
#  10  Price             1273 non-null   float64
# dtypes: float64(3), int32(1), object(7)
# memory usage: 114.4+ KB

# %% [markdown]
# # Finding Invalid Values

# %%
# Unique values of each columns in the dataframe

laptop_df.apply(lambda x : x.unique())
# Out:
# Company             [Apple, HP, Acer, Asus, Dell, Lenovo, Chuwi, M...
# TypeName            [Ultrabook, Notebook, Gaming, 2 in 1 Convertib...
# Inches              [13.3, 15.6, 15.4, 14.0, 12.0, 17.3, 13.5, 12....
# ScreenResolution    [IPS Panel Retina Display 2560x1600, 1440x900,...
# Cpu                 [Intel Core i5 2.3GHz, Intel Core i5 1.8GHz, I...
# Ram in GB                         [8, 16, 4, 2, 12, 64, 6, 32, 24, 1]
# Memory              [128GB SSD, 128GB Flash Storage, 256GB SSD, 51...
# Gpu                 [Intel Iris Plus Graphics 640, Intel HD Graphi...
# OpSys               [macOS, No OS, Windows 10, Mac OS X, Linux, Wi...
# Weight in kg        [1.37, 1.34, 1.86, 1.83, 2.1, 2.04, 1.3, 1.6, ...
# Price               [71378.68, 47895.52, 30636.0, 135195.34, 96095...
# dtype: object

# %%
print(laptop_df['Inches'].describe())
print(laptop_df['Ram in GB'].value_counts())
print(laptop_df['Price'].describe())
# Out:
# count    1273.000000
# mean       15.420031
# std         4.952272
# min         2.100000
# 25%        14.000000
# 50%        15.600000
# 75%        15.600000
# max       111.800000
# Name: Inches, dtype: float64
# Ram in GB
# 8     608
# 4     362
# 16    194
# 6      39
# 12     24
# 2      22
# 32     17
# 64      3
# 24      3
# 1       1
# Name: count, dtype: int64
# count      1273.000000
# mean      59955.814077
# std       37332.251033
# min        9270.720000
# 25%       31914.720000
# 50%       52161.120000
# 75%       79333.390000
# max      324954.720000
# Name: Price, dtype: float64

# %% [markdown]
# # Handling Duplicates

# %%
# Finding duplicates
duplicates = laptop_df[laptop_df.duplicated()]
print("Number of duplicate rows:", len(duplicates))
print(duplicates)
# Out:
# Number of duplicate rows: 28
#      Company            TypeName  Inches  \
# 1274    Asus            Notebook    15.6
# 1275    Asus           Ultrabook    13.3
# 1276    Dell            Notebook    15.6
# 1277    Acer            Notebook    15.6
# 1278    Dell            Notebook    15.6
# 1279  Lenovo            Notebook    15.6
# 1280      HP            Notebook    15.6
# 1281    Dell            Notebook    15.6
# 1282      HP             Netbook    11.6
# 1283    Asus            Notebook    15.6
# 1284  Lenovo  2 in 1 Convertible    14.0
# 1285  Lenovo  2 in 1 Convertible    13.3
# 1286  Lenovo            Notebook    14.0
# 1287      HP            Notebook    15.6
# 1288    Asus            Notebook    15.6
# 1289    Asus           Ultrabook    13.3
# 1290    Dell            Notebook    15.6
# 1291    Acer            Notebook    15.6
# 1292    Dell            Notebook    15.6
# 1293  Lenovo            Notebook    15.6
# 1294      HP            Notebook    15.6
# ...

# %%
laptop_df.drop_duplicates(inplace=True)

# %%
laptop_df.shape
# Out:
# (1245, 11)

# %%
laptop_df.isnull().sum()
# Out:
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram in GB           0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight in kg        0
# Price               0
# dtype: int64

# %% [markdown]
# # Check for Outliers

# %%
# Price column
plt.figure(figsize=(10, 5))
sns.boxplot(x=laptop_df["Price"], color="#F4A261")
plt.title("Boxplot of Laptop Price")
plt.xlabel("Price")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x=laptop_df["Weight in kg"],color="#F4A261")
plt.title("Laptop Weight Distribution")
plt.xlabel("Weight in KG")
plt.show()

# %%
# Step 1: Calculate Q1, Q3 and IQR for Weight
Q1 = laptop_df['Weight in kg'].quantile(0.25)
Q3 = laptop_df['Weight in kg'].quantile(0.75)
IQR = Q3 - Q1

# Step 2: Set lower and upper bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Step 3: Filter the DataFrame
laptop_df = laptop_df[(laptop_df['Weight in kg'] >= lower_bound) & (laptop_df['Weight in kg'] <= upper_bound)]

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x=laptop_df["Weight in kg"],color="#F4A261")
plt.title("Laptop Weight After removed Outliers ")
plt.xlabel("Weight in KG")
plt.show()

# %%
# Assuming your dataset is loaded in a DataFrame called 'df' and the column with screen sizes is 'inches'

# Calculate the IQR for the 'inches' column
Q1 = laptop_df['Inches'].quantile(0.25)
Q3 = laptop_df['Inches'].quantile(0.75)
IQR = Q3 - Q1

# Define the lower and upper bounds for acceptable values
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Remove rows where 'inches' is outside of the IQR range
df_cleaned = laptop_df[(laptop_df['Inches'] >= lower_bound) & (laptop_df['Inches'] <= upper_bound)]

# %%
# Inches column
plt.figure(figsize=(10, 5))
sns.boxplot(x=laptop_df["Inches"], color="#F4A261")
plt.title("Boxplot of Screen Size")
plt.xlabel("Inches")
plt.show()

# %%
# Ram Column
plt.figure(figsize=(10, 5))
sns.boxplot(x=laptop_df["Ram in GB"], color="#F4A261")
plt.title("Boxplot of Ram")
plt.xlabel("Ram in GB")
plt.show()

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ### Brand Reputation

# %%
# Assign reputation score based on average price (or market knowledge if available)
brand_avg_price = laptop_df.groupby('Company')['Price'].mean().sort_values(ascending=False)
laptop_df['Brand_Reputation'] = laptop_df['Company'].map(brand_avg_price)
brand_avg_price
# Out:
# Company
# Razer        178282.491429
# LG           111834.720000
# Google        89386.080000
# Microsoft     85903.788333
# MSI           85619.064889
# Apple         83340.499524
# Huawei        75870.720000
# Samsung       75308.320000
# Toshiba       67632.010435
# Xiaomi        60390.882500
# Dell          58940.699242
# HP            57702.937266
# Lenovo        57499.097823
# Asus          55423.039118
# Fujitsu       38574.720000
# Acer          31094.379896
# Chuwi         16745.726667
# Mediacom      15717.600000
# Vero          11584.402500
# Name: Price, dtype: float64

# %% [markdown]
# ### Processor Generation

# %%
import re

def infer_gen_from_ghz(ghz):
    ghz = float(ghz)
    if ghz <= 2.0:
        return "5 Gen"
    elif 2.0 < ghz <= 2.5:
        return "6 Gen"
    elif 2.5 < ghz <= 2.8:
        return "8 Gen"
    elif 2.8 < ghz <= 3.1:
        return "9 Gen"
    elif 3.1 < ghz <= 3.3:
        return "11 Gen"
    elif ghz > 3.3:
        return "13 Gen"
    else:
        return "Unknown"

def extract_gen_or_estimate(cpu):
    if not isinstance(cpu, str):
        return "Unknown"

    # Try extracting gen from model number
    match = re.search(r'[iI][3579]\s?-?\s?(\d{4,5})', cpu)
    if match:
        number = match.group(1)
        if len(number) == 4:
            return f"{int(number[0])} Gen"  # e.g., 7200 -> 7 Gen
        elif len(number) == 5:
            return f"{int(number[:2])} Gen"  # e.g., 1135G7 -> 11 Gen

    # Fallback: Estimate from GHz
    freq_match = re.search(r'(\d\.\d+)\s?GHz', cpu)
    if freq_match:
        return infer_gen_from_ghz(freq_match.group(1))

    return "Unknown"

# Apply to DataFrame
laptop_df['CPU_Generation'] = laptop_df['Cpu'].astype(str).apply(extract_gen_or_estimate)

# Sample output
print(laptop_df[['Cpu', 'CPU_Generation']].head())
# Out:
#                           Cpu CPU_Generation
# 0        Intel Core i5 2.3GHz          6 Gen
# 1        Intel Core i5 1.8GHz          5 Gen
# 2  Intel Core i5 7200U 2.5GHz          7 Gen
# 3        Intel Core i7 2.7GHz          8 Gen
# 4        Intel Core i5 3.1GHz          9 Gen

# %% [markdown]
# ### Memory features

# %%
# Flag SSD presence
laptop_df['Has_SSD'] = laptop_df['Memory'].astype(str).apply(lambda x: 1 if 'SSD' in x else 0)

# Total memory in GB
def extract_total_memory(memory):
    nums = re.findall(r'(\d+)', str(memory))
    return sum([int(n) for n in nums]) if nums else None

laptop_df['Total_Memory_GB'] = laptop_df['Memory'].apply(extract_total_memory)
laptop_df['Total_Memory_GB']
# Out:
# 0       128
# 1       128
# 2       256
# 3       512
# 4       256
#        ...
# 1270    128
# 1271    512
# 1272     64
# 1273      1
# 1300     64
# Name: Total_Memory_GB, Length: 1185, dtype: int64

# %% [markdown]
# ### Operating System Types

# %%
def categorize_os(os):
    os = str(os).lower()
    if 'windows' in os:
        return 'Windows'
    elif 'mac' in os:
        return 'Mac'
    elif 'linux' in os:
        return 'Linux'
    else:
        return 'Other'

laptop_df['OS_Category'] = laptop_df['OpSys'].apply(categorize_os)
laptop_df['OS_Category']
# Out:
# 0           Mac
# 1           Mac
# 2         Other
# 3           Mac
# 4           Mac
#          ...
# 1270    Windows
# 1271    Windows
# 1272    Windows
# 1273    Windows
# 1300    Windows
# Name: OS_Category, Length: 1185, dtype: object

# %% [markdown]
# ### Dimensionality Reduction

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# Select numeric features only
numeric_features = laptop_df.select_dtypes(include=['float64', 'int64']).drop(columns=['Price'])

# %%
# Standardize
scaler = StandardScaler()
scaled_features = scaler.fit_transform(numeric_features)
scaled_features
# Out:
# array([[-0.421022  , -1.12453578,  1.66851363,  0.73822791, -0.56470249],
#        [-0.421022  , -1.18102475,  1.66851363, -1.35459523, -0.56470249],
#        [ 0.06319416, -0.20188254, -0.02764366,  0.73822791,  0.16600339],
#        ...,
#        [-0.27365186, -0.87975022, -0.04112948, -1.35459523, -0.93005542],
#        [ 0.06319416,  0.41949618, -0.02764366, -1.35459523, -1.28969972],
#        [10.54752675, -0.87975022, -0.04112948, -1.35459523, -0.93005542]])

# %%
# Apply PCA
pca = PCA(n_components=0.95)  # retain 95% of the variance
pca_features = pca.fit_transform(scaled_features)
pca_features
# Out:
# array([[ 1.30714946, -0.19239368,  1.30536648, -1.05198308,  0.73030283],
#        [ 0.15060667, -0.74307488,  1.64998898, -1.60845283, -0.79082682],
#        [ 0.56788309,  0.12690211, -0.28117681,  0.0653476 ,  0.44286087],
#        ...,
#        [-0.90287314, -1.12779228,  0.47358921, -1.07127487, -0.30241829],
#        [-1.68448108, -0.21744298,  0.75552184, -0.44687499, -0.15401244],
#        [-2.90817291,  6.53362024, -4.2744717 , -6.70743525, -0.56519453]])

# %%
# Add back to DataFrame if needed
pca_df = pd.DataFrame(pca_features, columns=[f'PC{i+1}' for i in range(pca_features.shape[1])])
pca_df
# Out:
#            PC1       PC2       PC3       PC4       PC5
# 0     1.307149 -0.192394  1.305366 -1.051983  0.730303
# 1     0.150607 -0.743075  1.649989 -1.608453 -0.790827
# 2     0.567883  0.126902 -0.281177  0.065348  0.442861
# 3     2.118526  0.837024  0.483310 -0.026847 -0.788371
# 4     1.720726 -0.110752  1.032646 -0.835798  0.245424
# ...        ...       ...       ...       ...       ...
# 1180  0.256534 -0.259554  0.104182 -0.050517  0.944987
# 1181  1.902211 -0.631441 -0.855937  0.015173 -0.448136
# 1182 -0.902873 -1.127792  0.473589 -1.071275 -0.302418
# 1183 -1.684481 -0.217443  0.755522 -0.446875 -0.154012
# 1184 -2.908173  6.533620 -4.274472 -6.707435 -0.565195
#
# [1185 rows x 5 columns]

# %%
import pandas as pd
from scipy.stats import ttest_ind, f_oneway

# %% [markdown]
# # Hyphothesis Testing

# %% [markdown]
# ## 1.Does the RAM size impacts the laptop Price ?

# %%
# T - Test

# 1. RAM: High (>=8) vs Low (<8)
low_ram = laptop_df[laptop_df['Ram in GB'] < 8]['Price'].dropna()
high_ram = laptop_df[laptop_df['Ram in GB'] >= 8]['Price'].dropna()
tstat_ram, pval_ram = ttest_ind(high_ram, low_ram, equal_var=False)
pval_ram
# Out:
# 5.022509265025481e-144

# %% [markdown]
# # Inference
#
# ### Definitely the RAM impacts the  laptop price

# %% [markdown]
# ## 2.Does the Operating System impacts the Price of the laptop ?

# %%
from scipy.stats import f_oneway

# One Way ANOVA
# Group price data by OpSys
groups = laptop_df.groupby('OpSys')['Price'].apply(list)

# Perform one-way ANOVA
f_stat, p_value = f_oneway(*groups)

print(f"F-statistic: {f_stat}")
print(f"P-value: {p_value}")
# Out:
# F-statistic: 19.39723204158734
# P-value: 1.258171543820101e-27

# %% [markdown]
# # Inference
#
# #### The operation system impacts price

# %% [markdown]
# ## 3.Does the brand impacts the price?

# %%
from scipy.stats import f_oneway

# Group price data by OpSys
groups = laptop_df.groupby('Company')['Price'].apply(list)

# Perform one-way ANOVA
f_stat, p_value = f_oneway(*groups)

print(f"F-statistic: {f_stat}")
print(f"P-value: {p_value}")
# Out:
# F-statistic: 14.92300380511933
# P-value: 1.8229457503047496e-41

# %% [markdown]
# # Inference
#
# #### The brand of the laptop definitely impacts the price

# %% [markdown]
# # Exploratory Data Analysis - EDA

# %% [markdown]
# ### Univariate Analysis

# %%
# Chart 1: Distribution of Laptop Prices
plt.figure(figsize=(12,5))
sns.histplot(laptop_df['Price'], kde=True, bins=30,color="#D5B942")
plt.title('Distribution of Laptop Price')
plt.xlabel('Price')
plt.ylabel('Count')
plt.show()

# %%
# Distribution of Ram
plt.figure(figsize=(8,5))
sns.histplot(laptop_df["Ram in GB"],kde=True,bins=15)
plt.title("Distribution of Ram")
plt.xlabel("Ram in GB")
plt.ylabel("Count")
plt.show()

# %%
top_10_resolutions = laptop_df['ScreenResolution'].value_counts().head(10).index

# %%
filtered_df = laptop_df[laptop_df['ScreenResolution'].isin(top_10_resolutions)]

# %%
# Distribution of Weight

plt.figure(figsize=(8,5))
sns.histplot(laptop_df["Weight in kg"],kde=True,bins=30,color="#666A86")
plt.title("Distribution of Weight")
plt.xlabel("Weight in kg")
plt.ylabel("Count")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(16,5))
sns.boxplot(x=laptop_df["Company"])
plt.title("Distribution of Company")
plt.xlabel("Company")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(16,5))
sns.boxplot(x=laptop_df["TypeName"])
plt.title("Distribution of TypeName")
plt.xlabel("TypeName")
plt.ylabel("Count")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(16,5))
sns.histplot(x=laptop_df["OpSys"])
plt.title("Distribution of OpSys")
plt.xlabel("OS")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# # Bivariate Analysis

# %%
# Function to remove outliers based on IQR for each group (RAM)
def remove_outliers_iqr(df, col, group_col):
    def iqr_filter(group):
        Q1 = group[col].quantile(0.25)
        Q3 = group[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        return group[(group[col] >= lower_bound) & (group[col] <= upper_bound)]
    
    return df.groupby(group_col, group_keys=False).apply(iqr_filter)

# Apply to your dataset
laptop_df_cleaned = remove_outliers_iqr(laptop_df, 'Price', 'Ram in GB')

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x='Ram in GB', y='Price', data=laptop_df_cleaned)
plt.title('Price vs RAM (Outliers Removed)')
plt.show()

# %%
# Step 1: Get top 10 most frequent CPUs
top_10_cpus = laptop_df['Cpu'].value_counts().nlargest(10).index

# Step 2: Filter only those rows with top 10 CPUs
top_cpu_df = laptop_df[laptop_df['Cpu'].isin(top_10_cpus)]

# Optional: Remove outliers in price (if needed)
Q1 = top_cpu_df['Price'].quantile(0.25)
Q3 = top_cpu_df['Price'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

top_cpu_df = top_cpu_df[(top_cpu_df['Price'] >= lower_bound) & (top_cpu_df['Price'] <= upper_bound)]

# Step 3: Plot
plt.figure(figsize=(14, 6))
sns.barplot(x='Cpu', y='Price', data=top_cpu_df, ci='sd', palette='magma')
plt.title('Price vs Top 10 Most Common CPUs')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Step 1: Get top 10 most frequent CPU types
top_10_cpus = laptop_df['Cpu'].value_counts().head(10).index

# Step 2: Filter the DataFrame to only include those top 10 CPUs
filtered_cpu_df = laptop_df[laptop_df['Cpu'].isin(top_10_cpus)]

# Step 3: Plot
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Cpu', y='Price', data=filtered_cpu_df, color="#b08968")
plt.title('Price vs Top 10 CPU Types')
plt.xlabel('CPU')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Step 1: Calculate Q1, Q3 and IQR
Q1 = laptop_df['Price'].quantile(0.25)
Q3 = laptop_df['Price'].quantile(0.75)
IQR = Q3 - Q1

# Step 2: Define lower and upper bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Step 3: Filter the DataFrame to keep only non-outliers
laptop_df_cleaned = laptop_df[(laptop_df['Price'] >= lower_bound) & (laptop_df['Price'] <= upper_bound)]

# %%
plt.figure(figsize=(16, 6))
sns.barplot(x='OpSys', y='Price',color="#b08968",data=laptop_df)
plt.xticks(rotation=45)
plt.title('OpSys vs Price')
plt.show()

# %%
# Price vs Inches
plt.figure(figsize=(16,5))
sns.barplot(x='Company', y='Price', color="#b08968",data=laptop_df)
plt.title('Company vs Price')
plt.show()

# %% [markdown]
# # Multivariate Analysis

# %%
# Price vs RAM grouped by Type
plt.figure(figsize=(10,6))
sns.barplot(x='Ram in GB', y='Price', hue='TypeName', data=laptop_df)
plt.title('Price vs RAM by Laptop Type')
plt.show()

# %%
# Correlation Heatmap
plt.figure(figsize=(8,6))
sns.heatmap(laptop_df.corr(numeric_only=True), annot=True, cmap="Blues")
plt.title('Correlation Heatmap')
plt.show()

# %%
def remove_outliers_iqr(df, columns):
    for col in columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        df = df[(df[col] >= lower_bound) & (df[col] <= upper_bound)]
    return df

# List of columns for outlier removal
cols_to_check = ['Price', 'Ram in GB', 'Inches', 'Weight in kg']
clean_df = remove_outliers_iqr(laptop_df, cols_to_check)

# Plot pairplot without outliers
sns.pairplot(clean_df[cols_to_check])
plt.show()

# %%
# Price vs Screen Size colored by OS
plt.figure(figsize=(10,6))
sns.scatterplot(data=laptop_df, x='Inches', y='Price', hue='OpSys',color="#")
plt.title('Price vs Screen Size Colored by OS')
plt.show()

# %% [markdown]
# # Insights

# %% [markdown]
# 1.Most of laptop price between 25k – 60k.
#
# 2.Laptop price above 1 lakh are less counts.
#
# 3.Most laptop have 8 GB RAM followed by 4 GB and 16 GB.
#
# 4.Most of the Laptop weight 1.8 kg – 2.2kg.
#
# 5.Few laptos are in 2.8kg – 3.5kg are less.
#
# 6.Apple, Asus, Dell, HP, Lenovo, Acer and Microsoft have more counts.
#
# 7.Ultrabook, Notebook, Gaming most used Type.
#
# 8.As RAM size increases Price also increases.
#
# 9.CPU – i7 laptop are High price and i3 are low price.
#
# 10.macOS and windows are High price and Android and Chrome OS are low prices.
#
# 11.Brands – Razer, LG, Microsoft, Apple are high price.
#
# 12.Most laptops have Windows OS.
#
# 13.Most laptops 15.5 inches screen.

# %% [markdown]
# # Recommendations

# %% [markdown]
# 1.Budget friendly laptops with best specifications.
#
# 2.Reducing weight in laptops.
#
# 3.Reduce price on Apple so macOS will use widely.
#
# 4.Improve performance and specifications with OS.
#
# 5.Improving battery performance.
#
# 6.Reduce heat production on every laptops.
